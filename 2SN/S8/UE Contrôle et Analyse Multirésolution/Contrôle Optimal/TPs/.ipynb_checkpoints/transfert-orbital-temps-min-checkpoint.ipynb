# %% [markdown]
# [<img src="https://gitlab.irit.fr/toc/etu-n7/controle-optimal/-/raw/master/ressources/inp-enseeiht.jpg" alt="N7" height="100"/>](https://gitlab.irit.fr/toc/etu-n7/controle-optimal)

# %% [markdown]
# - Nom : SOTORIVA LERMEN
# - Prénom : Thiago

# %% [markdown]
# # Transfert orbital en temps minimal
#
# Ce sujet (ou TP-projet) est à rendre (voir la date sur moodle et les modalités du rendu) et sera évalué pour faire partie de la note finale de la matière Contrôle Optimal.
#
# ----
#
# On considère le problème du transfert d'un satellite d'une orbite initiale à l'orbite géostationnaire à temps minimal. Ce problème s'écrit comme un problème de contrôle optimal sous la forme
#
# $$
# \left\lbrace
# \begin{array}{l}
#     \min J(x, u, t_f) = t_f \\[1.0em]
#     \ \ \dot{x}_{1}(t) = ~ x_{3}(t)  \\[0.5em]
#     \ \ \dot{x}_{2}(t) = ~ x_{4}(t)  \\[0.5em]
#     \ \ \dot{x}_{3}(t) =  -\dfrac{\mu\, x_{1}(t)}{r^{3}(x(t))} + u_{1}(t)  \\[1em]
#     \ \ \dot{x}_{4}(t) =  -\dfrac{\mu\, x_{2}(t)}{r^{3}(x(t))} + u_{2}(t), ~~ ||u(t)|| \leq \gamma_\mathrm{max}, ~~ t \in [0,t_f] ~~ \text{p.p.}, ~~ u(t) = (u_1(t),u_2(t)),  \\[1.5em]
#     \ \ x_{1}(0)=x_{0,1}, ~~ x_{2}(0)=x_{0,2}, ~~ x_{3}(0)=x_{0,3}, ~~ x_{4}(0)=x_{0,4}, \\[1em]
#     \ \ r(x(t_f)) = r_{f}, ~~ x_{3}(t_f)=-\sqrt{\dfrac{\mu}{r_{f}^{3}}}x_{2}(t_f), ~~ x_{4}           (t_f)= \sqrt{\dfrac{\mu}{r_{f}^{3}}}x_{1}(t_f), \\
# \end{array}
# \right.
# $$
#
# avec $r(x)=\sqrt{x_{1}^{2}+x_{2}^{2}}$.
# Les unités choisies sont le kilomètre pour les distances et l'heure pour les  temps. On donne les paramètres suivants :
#
# $$
# \mu=5.1658620912 \times 10^{12} \ \mathrm{km}^{3}.\mathrm{h}^{-2}, \quad r_{f} = 42165 \ \mathrm{km}.
# $$
#
# Le paramètre $\gamma_\mathrm{max}$ dépend de la poussée maximale $F_\mathrm{max}$ suivant la relation :
#
# $$
# \gamma_\mathrm{max} = \frac{F_\mathrm{max}\times 3600^2}{m}
# $$
#
# où m est la masse du satellite qu'on fixe à $m=2000\ \mathrm{kg}$.

# %% [markdown]
# ## Résolution via du tir simple indirect

# %%
using DifferentialEquations, NLsolve, ForwardDiff, Plots, LinearAlgebra
include("utils.jl"); # fonctions utilitaires

# %%
# Les constantes du pb
x0     = [-42272.67, 0, 0, -5796.72] # état initial
μ      = 5.1658620912*1e12
rf     = 42165
F_max  = 100
γ_max  = F_max*3600^2/(2000*10^3)
t0     = 0
rf3    = rf^3
α      = sqrt(μ/rf3);

# %% [markdown]
# ✏️ **_Question 1:_**
#
# 1. Donner le pseudo-hamiltonien associé au problème de contrôle optimal.
# 2. Donner le pseudo système hamiltonien
# $$
#     \vec{H}(x, p, u) = \left(\frac{\partial H}{\partial p}(x, p, u),
#     -\frac{\partial H}{\partial x}(x, p, u) \right).
# $$
# 3. Calculer le contrôle maximisant. On supposera que $(p_3, p_4)\neq (0,0)$.

# %% [markdown]
# **Réponse**
#
# **1.**
#
# Le pseudo-hamiltonien :
#
# On a : $H(t,x,p,p^0,u) =  p.f(t,x,u) + p^0.f^0(t,x,u)$
#
# $p$ et $x$ sont écrits dans la façon fuivante $p = \begin{pmatrix}p1 \\ p2 \\
#                                         p3 \\ p4\\
#                                         \end{pmatrix} $, $x = \begin{pmatrix}x1 \\ x2 \\
#                                         x3 \\ x4\\
#                                         \end{pmatrix} $
# et comme le on travaille sur un problème de ransfert en temps minimal ($\min t_f$), alors $f^0 = 0$. On a aussi $f(t,x,u) = \begin{pmatrix} ~ x_{3}(t) \\
#                                                          ~ x_{4}(t) \\
#                                                          -\dfrac{\mu\, x_{1}(t)}{r^{3}(t)} + u_{1}(t) \\
#                                                          -\dfrac{\mu\, x_{2}(t)}{r^{3}(t)}+u_{2}(t) \\
#                                          \end{pmatrix} $
#
# Donc, le pseudo-hamiltoninen s'écrit :
#
# $H(x,p,u) =  p_{1}x_{3} + p_{2}x_{4} + p_{3}(-\dfrac{\mu\, x_{1}}{r^{3}} + u_{1}) + p_{4}(-\dfrac{\mu\, x_{2}}{r^{3}}+u_{2})$
#
# En remplacent $r$ par $\sqrt{x_{1}^{2}+x_{2}^{2}}$, alors on a :
#
# $H(x,p,u) = p_{1}x_{3} + p_{2}x_{4} + p_{3}(-\dfrac{\mu\, x_{1}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_{1}) + p_{4}(-\dfrac{\mu\, x_{2}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}}+u_{2})$
#
#
# **2.**
#
# Pseudo système hamiltonien :
#
# Après le calcul des dérivées de $H(x,p,u)$ par rapport à $p$ et $x$, on retrouve :
#
# $\frac{\partial H}{\partial p}(x, p, u) =  \begin{pmatrix}
# x_{3} \\
# x_{4} \\
# -\dfrac{\mu x_{1}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_1\\
# -\dfrac{\mu x_{2}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_2\\
# \end{pmatrix} $
#
#
# $\frac{\partial H}{\partial x}(x, p, u) = \begin{pmatrix}
# -\dfrac{\mu (3 p_4 x_1 x_2 + p_3(2 x_{1}^2 - x_{2}^2))}{(x_{1}^2 + x_{2}^2)^{5/2}} \\
# -\dfrac{\mu (3 p_3 x_1 x_2 + p_4(x_{1}^2 - 2 x_{2}^2))}{(x_{1}^2 + x_{2}^2)^{5/2}} \\
# p_{1} \\
# p_{2} \\
# \end{pmatrix}$
#
#
# On retrouve donc le pseudo-système hamiltonien :
#
# $\vec{H}(x, p, u) = \begin{pmatrix}
# x_{3} \\
# x_{4} \\
# -\dfrac{\mu x_{1}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_1\\
# -\dfrac{\mu x_{2}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_2\\
# \dfrac{\mu (3 p_4 x_1 x_2 + p_3(2 x_{1}^2 - x_{2}^2))}{(x_{1}^2 + x_{2}^2)^{5/2}} \\
# \dfrac{\mu (3 p_3 x_1 x_2 + p_4(x_{1}^2 - 2 x_{2}^2))}{(x_{1}^2 + x_{2}^2)^{5/2}} \\
# -p_{1} \\
# -p_{2}
# \end{pmatrix} =
# \begin{pmatrix}
# x_{3} \\
# x_{4} \\
# -\dfrac{\mu x_{1}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_1\\
# -\dfrac{\mu x_{2}}{(\sqrt{x_{1}^{2}+x_{2}^{2}})^{3}} + u_2\\
# \dfrac{\mu\, p_{3}(x_{2}^2-2x_{1}^2)}{({x_{1}^{2}+x_{2}^{2}})^{5/2}} - \dfrac{3\mu\, x_{1} x_{2} p_{4}}{({x_{1}^{2}+x_{2}^{2}})^{5/2}} \\
# \dfrac{\mu\, p_{4}(x_{1}^2-2x_{2}^2)}{({x_{1}^{2}+x_{2}^{2}})^{5/2}} - \dfrac{3\mu\, x_{1} x_{2} p_{3}}{({x_{1}^{2}+x_{2}^{2}})^{5/2}} \\
# -p_{1} \\
# -p_{2} \\
# \end{pmatrix}
# $
#
#
#
# **3.**
#
# On peut écrire le pseudo-hamiltonien sous la forme suivante :
#
# $H(x, p, u) = p_1x_3 + p_2x_4 + p_3(- \dfrac{\mu x_1}{(\sqrt{x_{1}^2 + x_{2}^2})^3}) + p_4(- \dfrac{\mu x_2}{(\sqrt{x_{1}^2 + x_{2}^2})^3}) + p_3u_1 + p_4u_2$
#
# Alors, on pose les vecteurs $u = \begin{pmatrix}
# u_{1} \\
# u_{2}
# \end{pmatrix}$ et $v = \begin{pmatrix}
# p_{3} \\
# p_{4}
# \end{pmatrix}$. On a que le système hamiltonien s'écrit sous la forme
#
# $$H(x,p,u) = H_0(x,p,u) + \langle u, v \rangle$$
#
# où $H_0(x,p,u) = p_1x_3 + p_2x_4 + p_3(- \dfrac{\mu x_1}{(\sqrt{x_{1}^2 + x_{2}^2})^3}) + p_4(- \dfrac{\mu x_2}{(\sqrt{x_{1}^2 + x_{2}^2})^3})$, avec $u \in \mathbb{R}^2$, $||u|| \leq  \gamma_\mathrm{max}$, $x \in \mathbb{R}^2, p \in \mathbb{R}^4$ et $v \in \mathbb{R}^2$.
#
# D'après l'inégalité de Cauchy-Schwartz,
#
# $$\langle u, v \rangle \leq ||u|| ||v|| \leq \gamma_\mathrm{max} ||v||$$.
#
# On sait que $(p_3, p_4) \leq (0, 0)$ et $||v|| = \sqrt{p_3^2 + p_4^2}$ alors ce maximum est atteint pour
#
# $$u[u,p] = \phi (u,p) = \frac{v \cdot \gamma_\mathrm{max}}{||v||} = \frac{(p_3, p_4) \cdot \gamma_\mathrm{max}}{\sqrt{p_3^2 + p_4^2}}$$

# %% [markdown]
# ✏️ **_Question 2:_** Compléter le code suivant contenant le pseudo-hamiltonien, le pseudo système hamiltonien et le contrôle maximisant.

# %%
#####
##### A COMPLETER

# pseudo-Hamiltonien
function H(x, p, u)
    r = sqrt(x[1]^2 + x[2]^2)
    h = p[1]*x[3] + p[2]*x[4] + p[3]*(((-μ*x[1])/(r^3))+u[1]) + p[4]*(((-μ*x[2])/(r^3))+u[2])
    return h
end

# pseudo système hamiltonien
function Hv(x, p, u)
    n     = size(x, 1)
    dx    = zeros(eltype(x), n)
    dp    = zeros(eltype(x), n)
    r = sqrt(x[1]^2 + x[2]^2)
    dp[1] = μ*p[3]*(r^2 - 3*(x[1]^2))/(r^5) - 3*μ*p[4]*x[1]*x[2]/(r^5)
    dp[2] = μ*p[4]*(r^2 - 3*(x[2]^2))/(r^5) - 3*μ*p[3]*x[1]*x[2]/(r^5)
    dp[3] = -p[1]
    dp[4] = -p[2]
    dx[1] = x[3]
    dx[2] = x[4]
    dx[3] = ((-μ*x[1])/(r^3))+u[1]
    dx[4] = ((-μ*x[2])/(r^3))+u[2]
    return dx, dp
end

# Contrôle maximisant
function control(p)
    u    = zeros(eltype(p),2)
    u[1] = (γ_max/(sqrt(p[3]^2 +p[4]^2)))*p[3]
    u[2] = (γ_max/(sqrt(p[3]^2 +p[4]^2)))*p[4]
    return u
end

#####
##### FIN A COMPLETER

# flot hamiltonien pour le calcul des extrémales
f = Flow((x, p) -> Hv(x, p, control(p)));

# %% [markdown]
# On note
# $
#     \alpha := \sqrt{\frac{\mu}{r_f^3}}.
# $
# La condition terminale peut se mettre sous la forme $c(x(t_f)) = 0$, avec $c \colon \mathbb{R}^4 \to \mathbb{R}^3$.
#
# ✏️ **_Question 3:_** Donner l'expression de $c(x)$.

# %% [markdown]
# **Réponse**
#
# $$
#     c(x) := (r^2(x) - r_{f}^2, x_{3} + \alpha\, x_{2}, x_{4} - \alpha\, x_{1}).
# $$

# %% [markdown]
# Le temps final étant libre, on a la condition au temps final
#
# $$
#     H(x(t_f), p(t_f), u(t_f)) = -p^0 = 1. \quad \text{(on se place dans le cas normal)}
# $$
#
# De plus, la condition de transversalité
#
# $$
# p(t_f) = c'(x(t_f))^T \lambda, ~~ \lambda \in \mathbb{R}^3,
# $$
#
# conduit à la relation suivante (où $\lambda$ n'apparaît plus)
#
# $$
# \Phi(x(t_f), p(t_f)) := x_2(t_f) \Big( p_1(t_f) + \alpha\, p_4(t_f) \Big) - x_1(t_f) \Big( p_2(t_f) - \alpha\, p_3(t_f) \Big) = 0.
# $$
#
# En considérant la condition aux limites, la condition finale sur le pseudo-hamiltonien et la condition de transversalité, la fonction de tir simple est donnée par
#
# \begin{equation*}
#     \begin{array}{rlll}
#         S \colon    & \mathbb{R}^5          & \longrightarrow   & \mathbb{R}^5 \\
#         & (p_0, t_f)      & \longmapsto       &
#         S(p_0, t_f) := \begin{pmatrix}
#             c(x(t_f, x_0, p_0)) \\[0.5em]
#             \Phi(z(t_f, x_0, p_0)) \\[0.5em]
#             H(z(t_f, x_0, p_0), u(z(t_f, x_0, p_0))) - 1
#         \end{pmatrix}
#     \end{array}
# \end{equation*}
#
# où $z(t_f, x_0, p_0)$ est la solution au temps $t_f$ du pseudo système hamiltonien bouclé par
# le contrôle maximisant, partant au temps $t_0=0$ du point $(x_0, p_0)$. On rappelle que l'on note
# $z=(x, p)$.

# %% [markdown]
# ✏️ **_Question 4:_** Compléter le code suivant de la fonction de tir.

# %%
#####
##### A COMPLETER

# Fonction de tir
function shoot(p0, tf)
    
    s = zeros(eltype(p0), 5)

    x,p = f(t0,x0,p0,tf)
        
    #Contrainte
    s[1] = sqrt(x[1]^2 + x[2]^2) - rf
    s[2] = x[3] + α*x[2]
    s[3] = x[4] - α*x[1]
    
    #Fonction phi
    s[4] = x[2]*(p[1] + α*p[4]) - x[1]*(p[2] - α*p[3])
    
    # Control
    u = control(p)
    
    #Hamiltonien
    Hfun = H(x,p,u)
    s[5] = Hfun - 1
    
    return s

end;

# %% [markdown]
# ✏️ **_Question 5:_** Expliquer simplement ce que fait le code suivant.

# %% [markdown]
# **Réponse**
#
# Le code suivante fait le calcul du controle optimal en utilisant la méthode de tir.
#
# D'abord on initiliase y_guess avec les valeurs unconnus de y qui sont les parametres du metrode de tir.
#
# foo (appel de la fonction tir) et jfoo sont les fonctions de tir. Après on utilise le resultat des fonctions foo et jfoo (jacobien) et on essaye de résoudre l'equation de foo(y) = 0.
#
# Donc, a chaque pas de optimisation on trouve un nouvelle solution en utilisant un solveur non-linéaire jusqu'à convergence de la méthode.

# %%
# Itéré initial
y_guess = [1.0323e-4, 4.915e-5, 3.568e-4, -1.554e-4, 13.4]   # pour F_max = 100N

# Jacobienne de la fonction de tir
foo(y)  = shoot(y[1:4], y[5])
jfoo(y) = ForwardDiff.jacobian(foo, y)

# Résolution de shoot(p0, tf) = 0
nl_sol = nlsolve(foo, jfoo, y_guess; xtol=1e-8, method=:trust_region, show_trace=true);

# On récupère la solution si convergence
if converged(nl_sol)
    p0_sol_100 = nl_sol.zero[1:4]
    tf_sol_100 = nl_sol.zero[5]
    println("\nFinal solution:\n", nl_sol.zero)
else
    error("Not converged")
end
# Out:
# Iter     f(x) inf-norm    Step 2-norm
# ------   --------------   --------------
#      0     4.208247e+02              NaN
#      1     3.419791e+00     3.507495e-03
#      2     8.493479e-02     3.222915e-04
#      3     4.221820e-07     3.247983e-06
#      4     5.384209e-10     2.965522e-10
#
# Final solution:
# [0.00010323118913618618, 4.892642781236129e-5, 0.00035679672939065, -0.000155361388628607, 13.403181957149352]

# %%
# Fonction d'affichage d'une solution
function plot_solution(p0, tf)

    # On trace l'orbite de départ et d'arrivée
    gr(dpi=300, size=(500,400), thickness_scaling=1)
    r0        = norm(x0[1:2])
    v0        = norm(x0[3:4])
    a         = 1.0/(2.0/r0-v0*v0/μ)
    t1        = r0*v0*v0/μ - 1.0;
    t2        = (x0[1:2]'*x0[3:4])/sqrt(a*μ);
    e_ellipse = norm([t1 t2])
    p_orb     = a*(1-e_ellipse^2);
    n_theta   = 101
    Theta     = range(0, stop=2*pi, length=n_theta)
    X1_orb_init = zeros(n_theta)
    X2_orb_init = zeros(n_theta)
    X1_orb_arr  = zeros(n_theta)
    X2_orb_arr  = zeros(n_theta)

    # Orbite initiale
    for  i in 1:n_theta
        theta = Theta[i]
        r_orb = p_orb/(1+e_ellipse*cos(theta));
        X1_orb_init[i] = r_orb*cos(theta);
        X2_orb_init[i] = r_orb*sin(theta);
    end

    # Orbite d'arrivée
    for  i in 1:n_theta
        theta = Theta[i]
        X1_orb_arr[i] = rf*cos(theta) ;
        X2_orb_arr[i] = rf*sin(theta);
    end;

    # Calcul de la trajectoire
    ode_sol  = f((t0, tf), x0, p0)
    t  = ode_sol.t
    x1 = [ode_sol[1, j] for j in 1:size(t, 1) ]
    x2 = [ode_sol[2, j] for j in 1:size(t, 1) ]
    u  = zeros(2, length(t))

    for j in 1:size(t, 1)
        u[:,j] = control(ode_sol[5:8, j])
    end

    px = plot(x1, x2, color=:red, legend=:best, label="Trajectoire",
        border=:none, size = (800,400), aspect_ratio=:equal)
    plot!(px, X1_orb_init, X2_orb_init, color=:green, label="Orbite initiale")
    plot!(px, X1_orb_arr, X2_orb_arr, color=:blue, label="Orbite d'arrivée")
    plot!(px, [x0[1]], [x0[2]], seriestype=:scatter, color=:green, markersize = 5, label="Départ")
    xf = ode_sol[1:2, end]
    plot!(px, [xf[1]], [xf[2]], seriestype=:scatter, color=:red, markersize = 5, label="Arrivée")
    plot!(px, [0.0], [0.0], color = :blue, seriestype=:scatter, markersize = 25, label="Terre")

    pu1 = plot(t, u[1,:], color=:red, label="u₁(t)", legend=:best)
    pu2 = plot(t, u[2,:], color=:red, label="u₂(t)", legend=:best)

    display(plot(pu1, pu2, layout = (1,2), size = (800,400)))
    display(px)
    display(plot(t, x2))
    
end;

# %%
# On affiche la solution pour Fmax = 100
plot_solution(p0_sol_100, tf_sol_100)

# %% [markdown]
# ✏️ **_Question 6:_** Que vaut le temps final $t_f$ (à 5 digits près) ? Combien de révolutions complètes autour de la Terre a réalisé le satellite.

# %%
max(tf_sol_100)
# Out:
# 13.403181957149352

# %% [markdown]
# **Réponse**
#
# Le temps final $t_f$ vaut 13.40318. Si on fait ´´´plot(t, x2)´´´ on peut verifier que le satelite fait 1 rotation complete autour de la Terre a cause de la variation de signe de x. On verifie que x2 change de signe 2 fois, e il complète la revolution à la fin (comme une rotation 2pi avec sin).

# %% [markdown]
# # Etude du temps de transfert en fonction de la poussée maximale
#
# ✏️ **_Question 7:_**
#
# * A l'aide de ce que vous avez fait précédemment, déterminer $t_f$ (attention, penser à bien itinialiser la
# méthode de tir) pour
#
# $$
#     F_\mathrm{max} \in \{100, 90, 80, 70, 60, 50, 40, 30, 20 \}.
# $$
#
# * Tracer ensuite $t_f$ en fonction de $F_\mathrm{max}$ et commenter le résultat.

# %% [markdown]
# **Réponse**
#
# En x nous avons la poussée maximale d’un satellite (F_max_span) et en y nous avons l’heure finale (tf_sols). Le graphique montre que lorsque la poussée maximale augmente, le temps de convergence diminue. Cette relation est logique car une poussée maximale plus élevée permet au satellite d’accélérer plus rapidement, lui permettant de couvrir la distance requise en moins de temps.

# %%
# Les différentes valeurs de poussées
F_max_span = range(100, stop=20, length=11);
γ_max_span = [F_max_span[j]*3600^2/(2000*10^3) for j in 1:size(F_max_span,1)];

# %%
# Solution calculée précédemment
y_guess = [p0_sol_100; [tf_sol_100]]

# Pour le stockage des solutions
tf_sols = zeros(length(γ_max_span))     # vecteur des temps de transfert
p0_sols = zeros(4, length(γ_max_span))  # matrice des co-états initiaux

#####
##### A COMPLETER

# On fait le meme chose que on a fait avant mais pour chaque valeur de gamma
for i in 1:length(γ_max_span)
    # On recupere les valeurs de gamma a chaque iteration
    γ_max = γ_max_span[i]
    # flot hamiltonien pour le calcul des extrémales
    f = Flow((x, p) -> Hv(x, p, control(p)));
    
    # Calcul de la fonction tir comme on a fait avant
    foo(y)  = shoot(y[1:4], y[5])
    jfoo(y) = ForwardDiff.jacobian(foo, y)

    # Résolution de la fonction foo(y) = 0
    nl_sol = nlsolve(foo, jfoo, y_guess; xtol=1e-8, method=:trust_region, show_trace=false);

    # On récupère la solution si convergence
    if converged(nl_sol)
        p0_sols[:,i] = nl_sol.zero[1:4]
        tf_sols[i] = nl_sol.zero[5]
        y_guess = [p0_sols[:,i]; [tf_sols[i]]]
        println("\nFinal solution:\n", nl_sol.zero)
    else
        error("Not converged")
    end
end
# Out:
# Final solution:
# [0.00010323118913618618, 4.892642781236129e-5, 0.00035679672939065, -0.000155361388628607, 13.403181957149352]
#
# Final solution:
# [8.581713189736767e-5, 4.8234340172800294e-5, 0.00035174966960542725, -0.0002655600836094207, 13.842412694293035]
#
# Final solution:
# [4.7010186574732015e-5, 4.453506776935796e-5, 0.00032477266855124347, -0.0004884780851598156, 14.38811273059913]
#
# Final solution:
# [-8.97584649258557e-5, 2.5783072334818304e-5, 0.0001880234526418991, -0.0012158766215542708, 15.168652689912872]
#
# Final solution:
# [-0.0005358485722273668, -3.773772826472275e-5, -0.00027520296538170063, -0.0035678596662532505, 16.78750785505443]
#
# Final solution:
# [-0.0005721785006617964, -3.2274637227392445e-5, -0.00023536328973784666, -0.003833598690785788, 19.548303893941043]
#
# Final solution:
# [-0.0004898952365456618, -1.0804071086081674e-5, -7.87888550223833e-5, -0.003456893915711814, 22.74183680057666]
#
# Final solution:
# [-0.0001288172964827078, 2.805980107798174e-5, 0.0002046265321150895, -0.001992582704941629, 28.224679830201445]
#
# Final solution:
# [-0.0005018309458711298, 6.028020714566735e-6, 4.39594340287891e-5, -0.0038914836937972265, 32.49705774620025]
#
# Final solution:
# [-0.0011246695138688609, -1.3113905314679913e-5, -9.563335675963487e-5, -0.006615505395248135, 42.60856002392831]
#
# Final solution:
# [-0.0013615711124372778, -7.349896979833983e-6, -5.359923708256414e-5, -0.008582713096395874, 59.855166890321556]

# %%
# Affichage de tf en fonction de la poussée maximale
plot(F_max_span, tf_sols, aspect_ratio=:equal, legend=:best, label="tf(Fmax)")

# %%
# Plots sol pour F_max = 20N
i = 11
γ_max = γ_max_span[i]
plot_solution(p0_sols[:, i], tf_sols[i])

# %% [markdown]
# # Animation
#
# Juste pour s'amuser

# %%
include("space.jl"); using .Space

# %%
# solution choice
i = 11
γ_max = γ_max_span[i] # γ_max must be updated for the use of the flow

# animation
# nFrame = 100; d = 30; fps = floor(Int, nFrame/d) => 2 minutes and 30 seconds of computation
nFrame = 100; d = 30; fps = floor(Int, nFrame/d)
Space.animation(p0_sols[:, i], tf_sols[i], f, γ_max, nFrame=nFrame, fps=fps)
# Out:
# Fps     = 3
# NFrame  = 100
# Vitesse = 0.3684871655899515
# Durée totale de la mission = 90.45995748580916 h
# InterruptException:
#
# Stacktrace:
#   [1] gr_display(plt::Plots.Plot{Plots.GRBackend}, dpi_factor::Float64)
#     @ Plots ~/.julia/packages/Plots/Hxe7H/src/backends/gr.jl:680
#   [2] #567
#     @ ~/.julia/packages/Plots/Hxe7H/src/backends/gr.jl:2014 [inlined]
#   [3] withenv(::Plots.var"#567#568"{Plots.Plot{Plots.GRBackend}, Float64}, ::Pair{String, String}, ::Vararg{Pair{String, String}})
#     @ Base ./env.jl:172
#   [4] _show(io::IOStream, #unused#::MIME{Symbol("image/png")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/Hxe7H/src/backends/gr.jl:2009
#   [5] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#   [6] invokelatest
#     @ ./essentials.jl:726 [inlined]
#   [7] show
#     @ ~/.julia/packages/Plots/Hxe7H/src/output.jl:237 [inlined]
#   [8] #336
#     @ ~/.julia/packages/Plots/Hxe7H/src/output.jl:6 [inlined]
#   [9] open(::Plots.var"#336#337"{Plots.Plot{Plots.GRBackend}}, ::String, ::Vararg{String}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:384
#  [10] open
#     @ ./io.jl:381 [inlined]
#  [11] png
#     @ ~/.julia/packages/Plots/Hxe7H/src/output.jl:6 [inlined]
#  [12] frame(anim::Animation, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/Hxe7H/src/animation.jl:26
#  [13] frame(anim::Animation)
#     @ Plots ~/.julia/packages/Plots/Hxe7H/src/animation.jl:24
#  [14] macro expansion
#     @ ~/.julia/packages/Plots/Hxe7H/src/animation.jl:226 [inlined]
#  [15] macro expansion
#     @ ~/Documents/ENSEEIHT-BigData/2SN/S8/UE Contrôle et Analyse Multirésolution/Contrôle Optimal/TPs/space.jl:352 [inlined]
#  [16] macro expansion
#     @ ~/.julia/packages/Plots/Hxe7H/src/animation.jl:245 [inlined]
#  [17] __animation(pre_transfert_data::Main.Space.PreTransfert, transfert_data::Main.Space.Transfert, post_transfert_data::Main.Space.PostTransfert, f0::Main.Space.var"#f#4"{Main.Space.var"#f#1#5"{Main.Space.var"#rhs!#3"{Main.Space.VectorField}}}, _γ_max::Float64; fps::Int64, nFrame::Int64)
#     @ Main.Space ~/Documents/ENSEEIHT-BigData/2SN/S8/UE Contrôle et Analyse Multirésolution/Contrôle Optimal/TPs/space.jl:308
#  [18] animation(p0::Vector{Float64}, tf::Float64, f::Function, γ_max::Float64; fps::Int64, nFrame::Int64)
#     @ Main.Space ~/Documents/ENSEEIHT-BigData/2SN/S8/UE Contrôle et Analyse Multirésolution/Contrôle Optimal/TPs/space.jl:125
#  [19] top-level scope
#     @ In[42]:8
#  [20] eval
#     @ ./boot.jl:368 [inlined]
#  [21] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428
